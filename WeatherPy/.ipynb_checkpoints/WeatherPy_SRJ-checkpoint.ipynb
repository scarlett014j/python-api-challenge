# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&q="

# %%
#cities_test = ["Paris", "London", "Oslo", "Beijing", "Mumbai", "Manila", "New York", "Seattle", "Dallas", "Taipei"]
city_name = []
city_temp = []
city_wind = []
city_clouds = []
city_humidity = []
city_lat = []
#city_lng = []
count  = 0
# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        weather_response = requests.get(query_url + city +"&units=imperial").json()
        city_name.append(weather_response["name"])
        city_temp.append(weather_response['main']['temp'])
        city_wind.append(weather_response['wind']['speed'])
        city_humidity.append(weather_response['main']['humidity'])
        city_clouds.append(weather_response['clouds']['all'])
        city_lat.append(weather_response['coord']['lat'])
        #city_lng.append(weather_response['coord']['lng'])
        print(f'Processing Record [{weather_response["name"]}]')
    except KeyError:
        print("city not found...skipping")
    count += 1
    if count == 499 :
        time.sleep(60)
        count = 0

print("----------------------------------\nDone")
# Out:
# Processing Record [Kargasok]
# Processing Record [Port Elizabeth]
# Processing Record [Pevek]
# Processing Record [San Mateo del Mar]
# Processing Record [Ixtapa]
# Processing Record [Ambovombe]
# Processing Record [Show Low]
# Processing Record [Mastic Beach]
# Processing Record [Pangnirtung]
# Processing Record [Vaini]
# Processing Record [Busselton]
# Processing Record [Paraíso]
# Processing Record [Mataura]
# Processing Record [Henties Bay]
# Processing Record [Bredasdorp]
# city not found...skipping
# Processing Record [Hilo]
# Processing Record [Hermanus]
# Processing Record [Sirte]
# Processing Record [Quartz Hill]
# Processing Record [Ihosy]
# Processing Record [Upernavik]
# Processing Record [São Sebastião]
# Processing Record [Grand Gaube]
# Processing Record [Zhigansk]
# Processing Record [Chichihualco]
# Processing Record [Montague]
# Processing Record [Hithadhoo]
# Processing Record [Ushuaia]
# Processing Record [Tuktoyaktuk]
# city not found...skipping
# Processing Record [Mar del Plata]
# Processing Record [Schaffhausen]
# Processing Record [Bambous Virieux]
# Processing Record [East London]
# Processing Record [Ilulissat]
# Processing Record [Bluff]
# Processing Record [Tiksi]
# Processing Record [Ginda]
# Processing Record [Podgornoye]
# Processing Record [Staryy Nadym]
# Processing Record [Harsīn]
# city not found...skipping
# Processing Record [Altay]
# Processing Record [Port Alfred]
# Processing Record [Bima]
# city not found...skipping
# Processing Record [Shimoda]
# Processing Record [Mossamedes]
# Processing Record [Yokadouma]
# city not found...skipping
# Processing Record [Mareeba]
# Processing Record [Atuona]
# Processing Record [Samarai]
# Processing Record [Jhang]
# Processing Record [Faya]
# Processing Record [Norman Wells]
# Processing Record [Severo-Kuril'sk]
# Processing Record [Rocha]
# Processing Record [Punta Arenas]
# Processing Record [Bilma]
# Processing Record [Belyy Yar]
# Processing Record [Caningay]
# Processing Record [Rikitea]
# Processing Record [Kaitangata]
# Processing Record [Vicksburg]
# Processing Record [Ostrovnoy]
# Processing Record [San Rafael]
# Processing Record [Fairbanks]
# Processing Record [Kiryat Gat]
# city not found...skipping
# Processing Record [Roald]
# Processing Record [Thompson]
# Processing Record [Saint Paul Harbor]
# Processing Record [Anadyr]
# Processing Record [Pierre]
# Processing Record [Kedrovyy]
# Processing Record [Souillac]
# Processing Record [Hobart]
# Processing Record [Arlit]
# city not found...skipping
# Processing Record [Tefé]
# Processing Record [Carutapera]
# Processing Record [Gweta]
# Processing Record [Longyearbyen]
# Processing Record [Barrow]
# Processing Record [Hong Kong]
# Processing Record [Klaksvík]
# Processing Record [Namatanai]
# Processing Record [Puerto Ayora]
# Processing Record [Manutuke]
# Processing Record [Imeni Poliny Osipenko]
# Processing Record [Clyde River]
# Processing Record [Qaanaaq]
# Processing Record [Carnarvon]
# Processing Record [Yellowknife]
# Processing Record [Yulara]
# Processing Record [Provideniya]
# Processing Record [Kapaa]
# Processing Record [Buchanan]
# city not found...skipping
# city not found...skipping
# Processing Record [Te Anau]
# city not found...skipping
# Processing Record [Nikolskoye]
# Processing Record [Padang]
# Processing Record [Chulym]
# Processing Record [Piterka]
# Processing Record [Touros]
# city not found...skipping
# Processing Record [Vila Franca do Campo]
# Processing Record [Tuluá]
# Processing Record [Bengkulu]
# Processing Record [Muros]
# city not found...skipping
# city not found...skipping
# Processing Record [Bulawayo]
# Processing Record [Jamestown]
# Processing Record [Codrington]
# Processing Record [Hangu]
# Processing Record [Ketchikan]
# Processing Record [Albany]
# Processing Record [Okhotsk]
# Processing Record [Constitución]
# Processing Record [Pisco]
# Processing Record [Hasaki]
# Processing Record [Chokurdakh]
# Processing Record [Vanimo]
# Processing Record [Cabo San Lucas]
# Processing Record [Ponta do Sol]
# Processing Record [Mount Gambier]
# Processing Record [São João da Barra]
# city not found...skipping
# city not found...skipping
# Processing Record [Vestmannaeyjar]
# Processing Record [Meitingen]
# Processing Record [Saiha]
# Processing Record [‘Ewa Beach]
# Processing Record [Torbay]
# Processing Record [Mt. Pleasant]
# Processing Record [Vardø]
# Processing Record [San Cristobal]
# Processing Record [New Norfolk]
# Processing Record [Castro]
# Processing Record [Lichuan]
# Processing Record [San Patricio]
# Processing Record [Talara]
# Processing Record [Saint-Philippe]
# Processing Record [Morristown]
# city not found...skipping
# city not found...skipping
# Processing Record [Kochubey]
# Processing Record [Sabha]
# Processing Record [Leningradskiy]
# Processing Record [Portland]
# Processing Record [Geraldton]
# Processing Record [Chilliwack]
# city not found...skipping
# Processing Record [Huarmey]
# city not found...skipping
# Processing Record [Nantucket]
# Processing Record [Dongsheng]
# Processing Record [Tezu]
# Processing Record [Minden]
# Processing Record [Cape Town]
# Processing Record [Fenoarivo]
# Processing Record [Pingliang]
# Processing Record [Grants]
# Processing Record [Aloleng]
# Processing Record [Beisfjord]
# Processing Record [Chivacoa]
# Processing Record [Sattahip]
# Processing Record [Port Blair]
# Processing Record [Esperance]
# Processing Record [Aklavik]
# Processing Record [Sunbury]
# Processing Record [Ahipara]
# Processing Record [Pangai]
# Processing Record [Aras]
# Processing Record [Chui]
# Processing Record [Elko]
# Processing Record [Fare]
# Processing Record [Kununurra]
# Processing Record [Ancud]
# Processing Record [Rosetta]
# Processing Record [Butaritari]
# city not found...skipping
# Processing Record [Kemijärvi]
# Processing Record [Nouakchott]
# Processing Record [Lorengau]
# Processing Record [Khatanga]
# Processing Record [Lernapat]
# Processing Record [São Filipe]
# Processing Record [Funtua]
# Processing Record [Saint George]
# Processing Record [Avarua]
# Processing Record [Big Bend]
# Processing Record [Sungai Penuh]
# Processing Record [Garmsār]
# Processing Record [Davila]
# Processing Record [Todos Santos]
# Processing Record [Dikson]
# Processing Record [Lüderitz]
# Processing Record [Katsuura]
# Processing Record [Ivanovka]
# Processing Record [Seoul]
# Processing Record [Tasiilaq]
# Processing Record [Atambua]
# Processing Record [Airai]
# Processing Record [Raja Jang]
# Processing Record [Sivaki]
# Processing Record [Maridi]
# Processing Record [George Town]
# Processing Record [Ribeira Grande]
# Processing Record [Tuatapere]
# Processing Record [Gafanha da Encarnação]
# city not found...skipping
# Processing Record [Marsá Maţrūḩ]
# Processing Record [Ozernovskiy]
# Processing Record [Sakakah]
# Processing Record [Maceió]
# Processing Record [Gisborne]
# Processing Record [Wanning]
# Processing Record [Necochea]
# city not found...skipping
# Processing Record [Joshīmath]
# city not found...skipping
# Processing Record [Lebu]
# Processing Record [Vågåmo]
# Processing Record [Kodyma]
# city not found...skipping
# Processing Record [Alta]
# Processing Record [Erzin]
# Processing Record [Lamar]
# Processing Record [Coos Bay]
# Processing Record [Puerto Carreño]
# Processing Record [Buala]
# Processing Record [Arraial do Cabo]
# Processing Record [Husavik]
# Processing Record [Vila]
# Processing Record [Mountmellick]
# Processing Record [Cayenne]
# Processing Record [Praia da Vitória]
# city not found...skipping
# Processing Record [Progreso]
# Processing Record [Vagay]
# Processing Record [Saint-François]
# Processing Record [Howard Springs]
# Processing Record [Aksarka]
# city not found...skipping
# Processing Record [Villefontaine]
# Processing Record [Olinda]
# Processing Record [Cap Malheureux]
# Processing Record [Yerbogachën]
# Processing Record [Bethel]
# Processing Record [Streletskoye]
# Processing Record [Port Augusta]
# Processing Record [Fort Nelson]
# Processing Record [Poum]
# Processing Record [Bria]
# Processing Record [Pouso Alegre]
# city not found...skipping
# city not found...skipping
# Processing Record [Parla]
# Processing Record [Trelew]
# city not found...skipping
# Processing Record [Sciacca]
# Processing Record [Lakselv]
# Processing Record [Cambrils]
# Processing Record [Thunder Bay]
# Processing Record [Skjervøy]
# Processing Record [Beian]
# Processing Record [Uyemskiy]
# Processing Record [Poddor'ye]
# Processing Record [Båtsfjord]
# Processing Record [Antofagasta]
# Processing Record [Myaundzha]
# Processing Record [Kodinsk]
# Processing Record [Leticia]
# Processing Record [At-Bashi]
# Processing Record [Olafsvik]
# Processing Record [Karaman Province]
# Processing Record [Pallasovka]
# Processing Record [Laguna]
# Processing Record [Kiruna]
# Processing Record [Pitimbu]
# city not found...skipping
# Processing Record [Semey]
# Processing Record [General Pico]
# Processing Record [Luba]
# Processing Record [Laas]
# Processing Record [Schisma Eloundas]
# Processing Record [Narsaq]
# Processing Record [Nanortalik]
# Processing Record [Bend]
# Processing Record [Bolshaya Dzhalga]
# Processing Record [Kisiwani]
# Processing Record [Qarqīn]
# Processing Record [Daru]
# Processing Record [Norfolk]
# Processing Record [Kazanskoye]
# Processing Record [Fortuna]
# Processing Record [Tautira]
# Processing Record [Saskylakh]
# Processing Record [Buy]
# Processing Record [Kahului]
# city not found...skipping
# Processing Record [Kutum]
# Processing Record [Kavieng]
# Processing Record [Nogliki]
# city not found...skipping
# Processing Record [Vostok]
# Processing Record [Port Hardy]
# Processing Record [Teruel]
# Processing Record [Rolla]
# Processing Record [Rosarito]
# Processing Record [Kalispell]
# Processing Record [Rancho Palos Verdes]
# Processing Record [Hemsedal]
# Processing Record [Zeya]
# Processing Record [Niksar]
# Processing Record [Lagoa]
# Processing Record [Eirunepé]
# Processing Record [Talnakh]
# Processing Record [Sistranda]
# Processing Record [Mackay]
# Processing Record [Mogadishu]
# Processing Record [Carupano]
# Processing Record [Luwuk]
# Processing Record [Berlevåg]
# Processing Record [Lumeje]
# Processing Record [Saint-Augustin]
# Processing Record [Gibsons]
# Processing Record [Kaeo]
# Processing Record [Samagaltay]
# Processing Record [Khani]
# Processing Record [Takāb]
# Processing Record [Dondo]
# Processing Record [Kieta]
# Processing Record [Sørland]
# Processing Record [Srednekolymsk]
# Processing Record [Mazsalaca]
# Processing Record [Iracoubo]
# city not found...skipping
# Processing Record [Dicabisagan]
# Processing Record [Noyabrsk]
# Processing Record [Korampallam]
# Processing Record [Haifa]
# Processing Record [Methven]
# city not found...skipping
# Processing Record [Rangpur City]
# Processing Record [Soe]
# Processing Record [Bharūch]
# Processing Record [Dunedin]
# Processing Record [Ambilobe]
# Processing Record [Cukai]
# Processing Record [Cherskiy]
# Processing Record [Robertsport]
# city not found...skipping
# Processing Record [Kouroussa]
# Processing Record [Atar]
# Processing Record [Evensk]
# Processing Record [Margate]
# Processing Record [La Ronge]
# city not found...skipping
# Processing Record [Yeppoon]
# Processing Record [St. George's]
# Processing Record [Yenagoa]
# Processing Record [Manyana]
# Processing Record [Mumbwa]
# Processing Record [Vung Tau]
# Processing Record [Zitacuaro]
# Processing Record [Mucurapo]
# Processing Record [Pinhão]
# Processing Record [Deputatsky]
# Processing Record [Dingle]
# Processing Record [Raja]
# Processing Record [Poya]
# city not found...skipping
# Processing Record [Coyhaique]
# Processing Record [Edd]
# Processing Record [Comodoro Rivadavia]
# Processing Record [Grindavik]
# Processing Record [Pringsewu]
# Processing Record [Yuyao]
# Processing Record [Bellingham]
# Processing Record [Buraidah]
# Processing Record [Homer]
# Processing Record [Rionero in Vulture]
# Processing Record [Hofn]
# Processing Record [Nouadhibou]
# Processing Record [Rio Grande]
# Processing Record [Lompoc]
# Processing Record [Wakkanai]
# Processing Record [Afşin]
# Processing Record [Honiara]
# Processing Record [Luau]
# Processing Record [Chipinge]
# city not found...skipping
# Processing Record [Tigil']
# Processing Record [Abdulino]
# Processing Record [Hamilton]
# Processing Record [Leshukonskoye]
# Processing Record [Whitehorse]
# Processing Record [Oistins]
# Processing Record [Hervey Bay]
# Processing Record [Haines Junction]
# Processing Record [Atbasar]
# city not found...skipping
# Processing Record [Chibombo]
# Processing Record [Mehamn]
# Processing Record [Yumen]
# Processing Record [Whitianga]
# Processing Record [Gorzów Wielkopolski]
# Processing Record [Beroroha]
# Processing Record [Mozarlândia]
# Processing Record [Soyo]
# city not found...skipping
# Processing Record [Mwene-Ditu]
# Processing Record [Oranjemund]
# Processing Record [Orissaare]
# Processing Record [Nhulunbuy]
# Processing Record [Kuytun]
# Processing Record [Limbang]
# Processing Record [Saldanha]
# Processing Record [Northam]
# Processing Record [Saryg-Sep]
# Processing Record [Galesong]
# Processing Record [Marzuq]
# Processing Record [Tartous]
# Processing Record [Adrar]
# Processing Record [Shirokiy]
# Processing Record [Cidreira]
# Processing Record [Chihuahua]
# Processing Record [Athabasca]
# Processing Record [Beyneu]
# Processing Record [Manakara]
# Processing Record [Watsa]
# Processing Record [Cimişlia]
# Processing Record [Iqaluit]
# Processing Record [Barcelos]
# Processing Record [Savé]
# Processing Record [Yaan]
# Processing Record [Buta]
# Processing Record [Luanda]
# Processing Record [Horsham]
# Processing Record [Iquitos]
# Processing Record [Aracati]
# Processing Record [Kabompo]
# Processing Record [Caravelas]
# Processing Record [Sitka]
# Processing Record [Vao]
# Processing Record [San Juan Bautista]
# Processing Record [Catuday]
# Processing Record [Tazovsky]
# Processing Record [Hobyo]
# Processing Record [Port Lincoln]
# Processing Record [Touho]
# Processing Record [Pleasanton]
# Processing Record [Goderich]
# Processing Record [Gonzales]
# Processing Record [San Quintín]
# Processing Record [Ossora]
# Processing Record [Lambaréné]
# Processing Record [Nome]
# Processing Record [Chicama]
# Processing Record [Pacific Grove]
# city not found...skipping
# Processing Record [Kloulklubed]
# Processing Record [Paita]
# Processing Record [Terrasini]
# Processing Record [Port Moresby]
# Processing Record [Inhuma]
# Processing Record [Kampot]
# Processing Record [Kragerø]
# Processing Record [Bathsheba]
# Processing Record [Iralaya]
# Processing Record [Bulancak]
# city not found...skipping
# Processing Record [Bac Lieu]
# Processing Record [Isla Mujeres]
# Processing Record [Djebeniana]
# city not found...skipping
# Processing Record [Ferkessédougou]
# Processing Record [Quelimane]
# city not found...skipping
# Processing Record [Vanavara]
# Processing Record [San Juan]
# Processing Record [Itarema]
# Processing Record [Saint-Pierre]
# Processing Record [Noumea]
# Processing Record [Redcar]
# Processing Record [Ponta Delgada]
# Processing Record [Palmer]
# Processing Record [College]
# Processing Record [Gachsaran]
# Processing Record [Mayo]
# city not found...skipping
# Processing Record [Gushikawa]
# Processing Record [Flin Flon]
# Processing Record [Dharampuri]
# Processing Record [Gujar Khan]
# Processing Record [Jimo]
# Processing Record [Paliā Kalān]
# Processing Record [Jinchang]
# Processing Record [Charters Towers]
# Processing Record [Djambala]
# city not found...skipping
# Processing Record [Qui Nhon]
# Processing Record [Kharabali]
# Processing Record [Dwārka]
# Processing Record [Salina Cruz]
# Processing Record [Sept-Îles]
# Processing Record [Price]
# Processing Record [Reconquista]
# Processing Record [Tuy Hoa]
# city not found...skipping
# Processing Record [Neepawa]
# Processing Record [Viedma]
# Processing Record [Gushi]
# Processing Record [Elliot]
# Processing Record [Rome]
# Processing Record [Sola]
# Processing Record [Severo-Yeniseyskiy]
# Processing Record [Abashiri]
# Processing Record [Sabang]
# Processing Record [Black River]
# city not found...skipping
# Processing Record [Korla]
# Processing Record [Lālmohan]
# Processing Record [Klyuchi]
# Processing Record [Xining]
# Processing Record [Lyubim]
# Processing Record [Shihezi]
# Processing Record [El Campo]
# Processing Record [Örnsköldsvik]
# Processing Record [Karasjok]
# Processing Record [Waitati]
# Processing Record [Cardston]
# Processing Record [Shitkino]
# Processing Record [Kruisfontein]
# city not found...skipping
# Processing Record [João Câmara]
# Processing Record [Mariehamn]
# Processing Record [Kutulik]
# Processing Record [Sainte-Maxime]
# Processing Record [Genhe]
# Processing Record [Acaraú]
# Processing Record [Sassandra]
# Processing Record [Newport]
# city not found...skipping
# Processing Record [Faanui]
# Processing Record [Nicoya]
# Processing Record [Tinglev]
# Processing Record [Baturaja]
# city not found...skipping
# Processing Record [Paysandu]
# Processing Record [Denizli Province]
# Processing Record [El Dorado]
# Processing Record [Havre-St-Pierre]
# Processing Record [Bogale]
# Processing Record [Purranque]
# Processing Record [Bajil]
# Processing Record [Pedersore]
# Processing Record [Labuhan]
# city not found...skipping
# Processing Record [Freeport]
# Processing Record [Kemin]
# Processing Record [Ubinskoye]
# Processing Record [Katherine]
# Processing Record [Sokoni]
# Processing Record [Mazatlán]
# Processing Record [Sivas Province]
# Processing Record [Turukhansk]
# Processing Record [Bintulu]
# Processing Record [Salta]
# Processing Record [Burē]
# Processing Record [Sal Rei]
# Processing Record [Storm Lake]
# Processing Record [Taiyuan]
# Processing Record [Pendleton]
# Processing Record [Kumul]
# Processing Record [Chengdu]
# Processing Record [Birao]
# Processing Record [Hirara]
# Processing Record [San Jose]
# Processing Record [Macusani]
# Processing Record [Chivolo]
# Processing Record [Kavaratti]
# Processing Record [Kysyl-Syr]
# Processing Record [Mount Isa]
# Processing Record [Isangel]
# Processing Record [Taganak]
# Processing Record [Tromsø]
# Processing Record [Malatya Province]
# Processing Record [Sibolga]
# Processing Record [Mitsamiouli]
# Processing Record [Gigmoto]
# Processing Record [Yar-Sale]
# Processing Record [Maināguri]
# Processing Record [Marawi]
# Processing Record [Harboøre]
# Processing Record [Nador]
# Processing Record [Kamenka]
# Processing Record [Kromy]
# Processing Record [Prymors'k]
# Processing Record [Bubaque]
# Processing Record [Tonj]
# Processing Record [Boldumsaz]
# Processing Record [Port Macquarie]
# Processing Record [Simitli]
# Processing Record [Lowell]
# Processing Record [Tura]
# Processing Record [Batagay-Alyta]
# Processing Record [Taber]
# Processing Record [Kajaani]
# Processing Record [Madanpur]
# Processing Record [Ahar]
# Processing Record [Tomatlán]
# Processing Record [Eina]
# Processing Record [Chegdomyn]
# Processing Record [Esim]
# Processing Record [Coquimbo]
# Processing Record [Batemans Bay]
# Processing Record [Dromolaxia]
# Processing Record [Mahébourg]
# Processing Record [Mindelo]
# Processing Record [Dornach]
# Processing Record [Los Llanos de Aridane]
# Processing Record [Chute-aux-Outardes]
# Processing Record [Cockburn Town]
# city not found...skipping
# Processing Record [Amapá]
# ----------------------------------
# Done

# %%
#putting the lists into a dictionary
weather_dict = {
    "City": city_name,
    "Lat": city_lat,
    "Max Temp": city_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind
}
#creating the dataframe from the weather dictionary and checking to make sure we have 500+ cities
weather_df= pd.DataFrame(weather_dict)
weather_df.describe()
# Out:
#               Lat    Max Temp    Humidity  Cloudiness  Wind Speed
# count  580.000000  580.000000  580.000000  580.000000  580.000000
# mean    21.307241   68.552207   70.950000   44.294828    7.336517
# std     33.501568   13.583204   20.169127   38.411295    4.928532
# min    -54.800000   30.200000   12.000000    0.000000    0.220000
# 25%     -6.487500   58.165000   59.000000    1.000000    3.645000
# 50%     28.475000   70.410000   74.000000   40.000000    5.860000
# 75%     49.775000   78.800000   87.000000   83.000000   10.290000
# max     78.220000   96.960000  100.000000  100.000000   27.940000

# %%
#writing CSV file to the output_data folder
weather_df.to_csv('output_data/weather_info.csv', index = False)

# %%
#humidity_sort = weather_df.sort_vales(by =['Humidity'])
#humidity_sort
weather_df2 = weather_df.sort_values(by = ['Humidity'])

# %%
weather_df2
# Out:
#              City    Lat  Max Temp  Humidity  Cloudiness  Wind Speed
# 73          Arlit  18.74     89.49        12          72       10.42
# 174  Saint George  37.10     92.25        13           1        6.93
# 529         Kumul  42.80     93.25        13           0       14.74
# 459      Jinchang  38.50     87.96        13           2       11.79
# 267        Qarqīn  37.42     96.96        14           0       14.70
# ..            ...    ...       ...       ...         ...         ...
# 249       Leticia  -4.22     75.20       100          75        0.78
# 242         Beian  63.66     56.30       100          75        5.82
# 507     El Dorado  33.21     73.20       100           1        4.23
# 98         Touros  -5.20     71.60       100          75        4.70
# 397         Watsa   3.04     61.07       100          47        1.48
#
# [580 rows x 6 columns]

# %%
#Latitude vs Temperature Plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolors = "blue", edgecolors = "black", alpha = 0.75)
plt.title("Latitude vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
x_values = weather_df["Lat"]
y_values = weather_df["Max Temp"]
plt.savefig('output_data/Latitude_vs_Temp')

# %%
#Latitude vs Humidity Plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolors = "blue", edgecolors = "black", alpha = 0.75)
plt.title("Latitude vs Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
x_values = weather_df["Lat"]
y_values = weather_df["Humidity"]
plt.savefig('output_data/Latitude_vs_Humidity')

# %%
#Latitude vs Cloudiness Plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", facecolors = "blue", edgecolors = "black", alpha = 0.75)
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
x_values = weather_df["Lat"]
y_values = weather_df["Cloudiness"]
plt.savefig('output_data/Latitude_vs_Cloudiness')

# %%
#Latitude vs Wind Speed Plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", facecolors = "blue", edgecolors = "black", alpha = 0.75)
plt.title("Latitude vs Wind Speed 07/26/2020")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
x_values = weather_df["Lat"]
y_values = weather_df["Wind Speed"]
plt.savefig('output_data/Latitude_vs_WindSpeed')

# %%
#separating by hemisphere
n_hemi = weather_df[weather_df ["Lat"]>= 0]
s_hemi = weather_df[weather_df ["Lat"]<0]

# %%
#linear regression function
def lin_reg(x,y):
    (slope, intercept, rvalue, pvalue,stderr) = linregress(x,y) 
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))
    return regress_values, line_eq, rvalue

# %%
#northern hemisphere- max temp vs latitude linear regression
x_values = n_hemi["Lat"]
y_values = n_hemi["Max Temp"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(6,10),fontsize= 15, color = "red")
plt.xlabel("Northern Hemisphere Latitude")
plt.ylabel("Max Temp (F)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/N_Latitude_vs_Temp')
plt.show()
# Out:
# The r-squared is: 0.422424071431855

# %%
#southern hemisphere- max temp vs latitude linear regression
x_values = s_hemi["Lat"]
y_values = s_hemi["Max Temp"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(-50,30),fontsize= 15, color = "red")
plt.xlabel("Southern Hemisphere Latitude")
plt.ylabel("Max Temp (F)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/S_Latitude_vs_Temp')
plt.show()
# Out:
# The r-squared is: 0.5199755468380092

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = n_hemi["Lat"]
y_values = n_hemi["Humidity"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(6,10),fontsize= 15, color = "red")
plt.xlabel("Northern Hemisphere Latitude")
plt.ylabel("Humidity (%)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/N_Latitude_vs_Humidity')
plt.show()
# Out:
# The r-squared is: 0.01397595610126434

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = s_hemi["Lat"]
y_values = s_hemi["Humidity"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(-50,20),fontsize= 15, color = "red")
plt.xlabel("Southern Hemisphere Latitude")
plt.ylabel("Humidity (%)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/S_Latitude_vs_Humidity')
plt.show()
# Out:
# The r-squared is: 3.444963376370864e-05

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = n_hemi["Lat"]
y_values = n_hemi["Cloudiness"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(25,55),fontsize= 15, color = "red")
plt.xlabel("Northern Hemisphere Latitude")
plt.ylabel("Cloudiness (%)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/N_Latitude_vs_Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.0008010238145861681

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = s_hemi["Lat"]
y_values = s_hemi["Cloudiness"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(-45,50),fontsize= 15, color = "red")
plt.xlabel("Southern Hemisphere Latitude")
plt.ylabel("Cloudiness (%)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/S_Latitude_vs_Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.011155818676023438

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = n_hemi["Lat"]
y_values = n_hemi["Wind Speed"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(6,10),fontsize= 15, color = "red")
plt.xlabel("Northern Hemisphere Latitude")
plt.ylabel("Wind Speed (mph)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/N_Latitude_vs_WindSpeed')
plt.show()
# Out:
# The r-squared is: 0.024771770687975547

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = s_hemi["Lat"]
y_values = s_hemi["Wind Speed"]
reg, lin_eq, rvalue = lin_reg(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, reg, "r-")
plt.annotate(lin_eq,(-50,10),fontsize= 15, color = "red")
plt.xlabel("Southern Hemisphere Latitude")
plt.ylabel("Wind Speed (mph)")
print("The r-squared is: " + str(rvalue**2))
plt.savefig('output_data/S_Latitude_vs_WindSpeed')
plt.show()
# Out:
# The r-squared is: 0.00013403450760090282
